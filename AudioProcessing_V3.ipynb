# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import accuracy_score, recall_score, precision_score
import math

# Importing the dataset
dataset = pd.read_csv('/content/drive/MyDrive/DataMining/Datasets/Copy of submission_1 - Copy of submission_1.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(dataset.groupby('class').mean())
# Out:
#             mfcc_m3  harmonics_m3  perceptrual_m3  zero_crossing_rate_m1  \
# class
# Extreme  -13.240599     -0.000022       -0.000039               0.030353
# Mild     -11.763545     -0.000075        0.000051               0.026570
# Minimal  -12.859073     -0.000006       -0.000011               0.025238
# Moderate -12.428453     -0.000006       -0.000008               0.028171
#
#           zero_crossing_rate_m2  zero_crossing_rate_m3  zero_crossing_rate_m5  \
# class
# Extreme                0.236496               0.090436               0.045306
# Mild                   0.239359               0.077691               0.049803
# Minimal                0.211818               0.070040               0.044560
# Moderate               0.246975               0.084318               0.051105
#
#           zero_crossing_rate_m6
# class
# Extreme                0.002684
# Mild                   0.003570
# Minimal                0.003293
# Moderate               0.003817

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import accuracy_score, recall_score, precision_score
import math

# Importing the dataset
dataset = pd.read_csv('/content/drive/MyDrive/DataMining/Datasets/submission_1.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
